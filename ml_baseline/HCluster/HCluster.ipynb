# %% [markdown]
# # KMeans Clustering
#
# import numpy as np
# from sklearn.cluster import KMeans
# from sklearn.preprocessing import StandardScaler
# import matplotlib
# import matplotlib.pyplot as plt

# %%
import numpy as np 
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler 
import matplotlib 
import matplotlib.pyplot as plt
from matplotlib import cm
import scipy.cluster.hierarchy as sch
from scipy.spatial.distance import cdist
import sys
sys.path.append('../')
from shared_modules.kmeans_graph_utils import elbow, silhouette, dendrogram
# Check the Matplotlib Version 
print ("Matplotlib Version", matplotlib.__version__)
# Out:
# Matplotlib Version 3.1.0

# %%
import pandas as pd
from sklearn.metrics import silhouette_samples, silhouette_score
   
weather_df = pd.read_csv('a1.txt', delim_whitespace = True)
mat = StandardScaler().fit_transform(weather_df);

# Scatter Graph of data
plt.scatter(mat[:,0],mat[:,1])

# %%
# Display the elbow graph
elbow(mat)
# Out:
# leaving elbow

# %%
silhouette(mat)
# Out:
# For n-clusers = 11 The average silhouette_score is : 0.5222744497322093
# For n-clusers = 12 The average silhouette_score is : 0.520814457096524
# For n-clusers = 13 The average silhouette_score is : 0.5191992912201424
# For n-clusers = 14 The average silhouette_score is : 0.5264396394936288
# For n-clusers = 15 The average silhouette_score is : 0.5379753674318682
# For n-clusers = 16 The average silhouette_score is : 0.538770407899492
# For n-clusers = 17 The average silhouette_score is : 0.5431536589929987
# For n-clusers = 18 The average silhouette_score is : 0.5479242033545068
# For n-clusers = 19 The average silhouette_score is : 0.5510648406000086
# For n-clusers = 20 The average silhouette_score is : 0.5601268179792919
# For n-clusers = 21 The average silhouette_score is : 0.5501913748198219
# For n-clusers = 22 The average silhouette_score is : 0.5454061851025215
# For n-clusers = 23 The average silhouette_score is : 0.5345869293122382
# ...

# %%
from sklearn import metrics
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# show a dendogram of the data
#dendrogram = sch.dendrogram(sch.linkage(mat, method='ward'))
dendrogram(mat)

# %%
set(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e4962b5c0078> in <module>
# ----> 1 set(labels)
#
# NameError: name 'labels' is not defined

# %% [markdown]
# #### This code does a heiarchical cluster

# %%
n_clusters = 20
model = AgglomerativeClustering(n_clusters=n_clusters, affinity='euclidean', linkage='ward')
model.fit(mat)
labels = model.labels_
print(set(labels))

for i in range(0,n_clusters):
    color = cm.nipy_spectral(float(i) / n_clusters)
    plt.scatter(mat[labels==i,0], mat[labels==i,1], s=50, marker='o',color=color)


#plt.scatter(mat[labels==1,0], mat[labels==1,1], s=50, marker='o',color='blue')
#plt.scatter(mat[labels==2,0], mat[labels==2,1], s=50, marker='o',color='green')
#plt.scatter(mat[labels==3,0], mat[labels==3,1], s=50, marker='o',color='purple')
#plt.scatter(mat[labels==4,0], mat[labels==4,1], s=50, marker='o',color='orange')
#plt.scatter(mat[labels==5,0], mat[labels==5,1], s=50, marker='o',color='yellow')
plt.show()
